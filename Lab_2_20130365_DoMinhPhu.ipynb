# %% [markdown]
# <a href="https://colab.research.google.com/github/MinhFus/MachineLearning/blob/MinhPhu-branch/Lab_2_20130365_DoMinhPhu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab #2
# This lab is the first step to get farmilliar with some common Machine Learning libraries, named ***Pandas*** and ***Matlotlib***.
#
# *   **Deadline: 23:59, 27/02/2023**

# %% [markdown]
# #0. Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/NLU'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/NLU

# %% [markdown]
# #1. Import libraries

# %%
# code
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv('shopping-data.csv')
dataset.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %% [markdown]
# #2. Load dataset
#
# *   Load dataset (named ***shopping-data.csv***) using ***read_csv*** from pandas
# *   Then, display 10 last examples

# %%
# code
import pandas as pd
dataset = pd.read_csv('shopping-data.csv')
dataset.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %% [markdown]
# #3. Show statistics of the given dataset

# %%
# code
dataset.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# #4. Sort dataset by ***Age***

# %%
# code
import pandas as pd
dataset.sort_values(by="Age")
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 114         115  Female   18                  65                      48
# 91           92    Male   18                  59                      41
# 65           66    Male   18                  48                      59
# 33           34    Male   18                  33                      92
# 0             1    Male   19                  15                      39
# ..          ...     ...  ...                 ...                     ...
# 90           91  Female   68                  59                      55
# 108         109    Male   68                  63                      43
# 57           58    Male   69                  44                      46
# 70           71    Male   70                  49                      55
# 60           61    Male   70                  46                      56
#
# [200 rows x 5 columns]

# %% [markdown]
# #5. Group dataset by ***Gender*** and ***Age***

# %%
# code
# dataset.sort_values(by="Age")
# dataset.sort_values(by="Genre")
print(dataset.groupby(['Age','Genre']).groups)
# Out:
# {(18, 'Female'): [114], (18, 'Male'): [33, 65, 91], (19, 'Female'): [111, 115], (19, 'Male'): [0, 61, 68, 113, 138, 162], (20, 'Female'): [2, 39], (20, 'Male'): [17, 99, 134], (21, 'Female'): [31, 35, 84, 105], (21, 'Male'): [1], (22, 'Female'): [5, 87], (22, 'Male'): [15], (23, 'Female'): [3, 7, 29, 78, 100, 124], (24, 'Female'): [13, 45], (24, 'Male'): [41, 95], (25, 'Female'): [132], (25, 'Male'): [21, 144], (26, 'Male'): [75, 103], (27, 'Female'): [47, 58, 97, 155], (27, 'Male'): [120, 177], (28, 'Female'): [142], (28, 'Male'): [145, 171, 187], (29, 'Female'): [48, 135, 161, 183], (29, 'Male'): [25], (30, 'Female'): [9, 37, 157, 159, 175], (30, 'Male'): [185, 199], (31, 'Female'): [4, 43, 49, 52, 125, 133, 163], (31, 'Male'): [23], (32, 'Female'): [69, 94, 143, 147, 181, 191], (32, 'Male'): [137, 141, 169, 197, 198], (33, 'Female'): [167], (33, 'Male'): [51, 192], (34, 'Female'): [88, 148, 190], (34, 'Male'): [149, 158], (35, 'Female'): [6, 11, 16, 19, 139, 195], (35, 'Male'): [2
# ...

# %% [markdown]
# #6. Use scatter plot to represent the relationship between ***Age*** and ***Annual Income***
# Rememer adding titles, xlabel, ylabel, ... to the plot

# %%
# code
import matplotlib.pyplot as plt
x_values = dataset['Age']
y_values = dataset['Annual Income (k$)']
plt.scatter(x_values,y_values, s=30, color="blue")
plt.title('Age and Annual Income')
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %% [markdown]
# #7. Use histogram plot to represent the distribution of ***Age***

# %%
#code
ages = dataset['Age']
range = (0, 100)
bins = 10
plt.hist(ages, bins ,range, color = 'blue', histtype='bar', rwidth =0.5)
plt.show()

# %% [markdown]
# #8. Finally,
# Save a copy in your Github. Remember renaming the notebook.
